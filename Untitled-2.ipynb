# %%
class LinkedList:
    def _init_(self):
        self.head = None #list is empty initially
    def insert_at_beginning(self, data): #Inserts a node at the beginning
     def insert_at_end (self, data): #Inserts a node at the end
        new_node = Node(data)
        if self.head is None:
           self.head = new_node
           return
        last = self.head #Traverse to the last node
        while last.next:
           last = last.next
           last.next = new_node
     def display(self): #Display all elements in the Linked List
        current = self.head
        if not current:
           print("The list is empty")
           return
        while current:
           print("current.data, end=")
           current = current.next
           print("None")
